# %%
import pandas as pd
df = pd.read_csv('taiwan_covid_19_daily_reports_vaccine_city.csv')
df.head()
# Out:
#       ID       Date             City Population Daily vaccinations  \
# 0  1,168  7/26/2021  New Taipei City  4,026,019               None
# 1  1,167  7/26/2021      Taipei City  2,574,704               None
# 2  1,172  7/26/2021   Kaohsiung City  2,758,494               None
# 3  1,170  7/26/2021    Taichung City  2,820,114               None
# 4  1,169  7/26/2021     Taoyuan City  2,270,939               None
#
#   Total vaccinations Percentage (%) Delivery (bottle) Remaining (bottle)  \
# 0          1,205,722         29.90%         1,397,834            264,080
# 1          1,039,014         40.40%         1,195,958            202,112
# 2            815,949         29.60%           906,742            144,784
# 3            796,772         28.30%           882,340            137,152
# 4            659,631         29.10%           780,286            168,906
#
#   Remaining (%)  ... Percentage (AZ,%) Delivery (AZ,doses)  \
# 0        18.90%  ...             16.51             853,700
# ...
